# %% [markdown]
# # **Todos os dados utilizados para confecção dos Dashboards são ficticios.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **DASHBOAD FINANCEIRO**

# %% [markdown]
# ![capa dash financeiro.png](data:image/png;base64,...)
#
#
#
# ![dash financeiro.png](data:image/png;base64,...)

# %% [markdown]
# ## **Para visualizar Acesse:**
#
# https://app.powerbi.com/view?r=eyJrIjoiNDFiMzgyYjMtMGI4OC00MzdhLTgzNGEtMDY5NjU1YTJhMTM4IiwidCI6ImJjNjIxZGVkLTgwNmQtNDE2NC04MzJmLTM3OGU1MjVhMWE3OCJ9&pageName=ReportSectiondd46dffaaf5bf47c8b5f

# %% [markdown]
# # **DASHBOARD VENDAS**

# %% [markdown]
# ![capa vendas sucos.png](data:image/png;base64,...)
#
#
# ![relatorio vendas sucos.png](data:image/png;base64,...)

# %% [markdown]
# ## **Para visualizar Acesse:**
#
# https://app.powerbi.com/view?r=eyJrIjoiMjE3ODcyMzAtNDk1OC00MzVhLTg0OTktNmI1NTZjMTY3OWQ0IiwidCI6ImJjNjIxZGVkLTgwNmQtNDE2NC04MzJmLTM3OGU1MjVhMWE3OCJ9

# %% [markdown]
# # **DASHBOARD GESTÃO DE PESSOAS**

# %% [markdown]
# ![relatorio GESTÃO DE PESSOAS.png](data:image/png;base64,...)

# %% [markdown]
# ## **Para visualizar Acesse:**
#
# https://app.powerbi.com/view?r=eyJrIjoiMjM3MTAzZGQtMDNmOC00NDEzLWIyOWYtOWY3Y2U3YWY3MDU2IiwidCI6ImJjNjIxZGVkLTgwNmQtNDE2NC04MzJmLTM3OGU1MjVhMWE3OCJ9

# %% [markdown]
# # **DASHBOARD FINANCEIRO**

# %% [markdown]
# ![CAPA RELATORIO FINANCEIRO.png](data:image/png;base64,...)
#
#
# ![RELATORIO FINANCEIRO.png](data:image/png;base64,...)

# %% [markdown]
# ## **Para visualizar Acesse:**
#
# https://app.powerbi.com/view?r=eyJrIjoiMTFkMzcyY2YtZTllNi00ODI2LTllMjAtNTkzMGY3ZTg5ZjNjIiwidCI6ImJjNjIxZGVkLTgwNmQtNDE2NC04MzJmLTM3OGU1MjVhMWE3OCJ9

# %% [markdown]
# # **DASHBOARD VENDAS**

# %% [markdown]
# ![RELATORIO vendass.png](data:image/png;base64,...)

# %% [markdown]
# ## **Para visualizar Acesse:**
#
# https://app.powerbi.com/view?r=eyJrIjoiODUxNDFkYWEtYjUzOS00ZGFkLWE2NWUtODE4MWM5NWE5ZWVhIiwidCI6ImJjNjIxZGVkLTgwNmQtNDE2NC04MzJmLTM3OGU1MjVhMWE3OCJ9
